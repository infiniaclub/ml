# %%
import numpy as np
import pandas as pd
from scipy.cluster.hierarchy import dendrogram,linkage


x = [8, 5, 10, 7, 3, 11, 14 , 16, 10, 12]
y = [21, 19, 24, 17, 16, 25, 24, 12, 21, 21]

data = list(zip(x, y))

model=linkage(data,method="complete",metric="euclidean")
dendrogram(model)
# Out:
# {'icoord': [[5.0, 5.0, 15.0, 15.0],
#   [25.0, 25.0, 35.0, 35.0],
#   [45.0, 45.0, 55.0, 55.0],
#   [30.0, 30.0, 50.0, 50.0],
#   [10.0, 10.0, 40.0, 40.0],
#   [85.0, 85.0, 95.0, 95.0],
#   [75.0, 75.0, 90.0, 90.0],
#   [65.0, 65.0, 82.5, 82.5],
#   [25.0, 25.0, 73.75, 73.75]],
#  'dcoord': [[0.0, 2.0, 2.0, 0.0],
#   [0.0, 1.4142135623730951, 1.4142135623730951, 0.0],
#   [0.0, 3.605551275463989, 3.605551275463989, 0.0],
#   [1.4142135623730951,
#    4.123105625617661,
#    4.123105625617661,
#    3.605551275463989],
#   [2.0, 6.708203932499369, 6.708203932499369, 4.123105625617661],
#   [0.0, 2.8284271247461903, 2.8284271247461903, 0.0],
#   [0.0, 4.123105625617661, 4.123105625617661, 2.8284271247461903],
#   [0.0, 13.601470508735444, 13.601470508735444, 4.123105625617661],
#   [6.708203932499369,
#    13.92838827718412,
#    13.92838827718412,
#    13.601470508735444]],
#  'ivl': ['0', '8', '2', '5', '6', '9', '7', '4', '1', '3'],
#  'leaves': [0, 8, 2, 5, 6, 9, 7, 4, 1, 3],
#  'color_list': ['C1', 'C1', 'C1', 'C1', 'C1', 'C2', 'C2', 'C0', 'C0'],
#  'leaves_color_list': ['C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C0',
#   'C2',
#   'C2',
#   'C2']}
